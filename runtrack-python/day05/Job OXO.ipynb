# %%
import pygame
from pygame.locals import *

# Constants
SCREEN_WIDTH = 600
SCREEN_HEIGHT = 600
GRID_SIZE = 200
GRID_ROWS = 3
GRID_COLS = 3
LINE_WIDTH = 15
X_COLOR = (255, 0, 0)
O_COLOR = (0, 191, 255)
LINE_COLOR = (255, 255, 255)  
BACKGROUND_COLOR = (211, 211, 211)  
FONT_SIZE = 48
GAME_FONT = None

# Initialize Pygame
pygame.init()
screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("TicTacToe1337")
GAME_FONT = pygame.font.Font(None, FONT_SIZE)

# Initialize game variables
board = [['' for _ in range(GRID_COLS)] for _ in range(GRID_ROWS)]
current_player = 'X'
winner = None
game_over = False

# Function to draw the grid
def draw_grid():
    screen.fill(BACKGROUND_COLOR)  
    for row in range(1, GRID_ROWS):
        pygame.draw.line(screen, LINE_COLOR, (0, row * GRID_SIZE), (SCREEN_WIDTH, row * GRID_SIZE), LINE_WIDTH)
    for col in range(1, GRID_COLS):
        pygame.draw.line(screen, LINE_COLOR, (col * GRID_SIZE, 0), (col * GRID_SIZE, SCREEN_HEIGHT), LINE_WIDTH)

# Function to draw X and O on the board
def draw_symbols():
    for row in range(GRID_ROWS):
        for col in range(GRID_COLS):
            if board[row][col] == 'X':
                x_pos = col * GRID_SIZE + GRID_SIZE // 2
                y_pos = row * GRID_SIZE + GRID_SIZE // 2
                pygame.draw.line(screen, X_COLOR, (x_pos - 60, y_pos - 60), (x_pos + 60, y_pos + 60), LINE_WIDTH)
                pygame.draw.line(screen, X_COLOR, (x_pos + 60, y_pos - 60), (x_pos - 60, y_pos + 60), LINE_WIDTH)
            elif board[row][col] == 'O':
                x_pos = col * GRID_SIZE + GRID_SIZE // 2
                y_pos = row * GRID_SIZE + GRID_SIZE // 2
                pygame.draw.circle(screen, O_COLOR, (x_pos, y_pos), 60, LINE_WIDTH)

# Function to check for a win
def check_win():
    for row in range(GRID_ROWS):
        if board[row][0] == board[row][1] == board[row][2] != '':
            return board[row][0]
    for col in range(GRID_COLS):
        if board[0][col] == board[1][col] == board[2][col] != '':
            return board[0][col]
    if board[0][0] == board[1][1] == board[2][2] != '':
        return board[0][0]
    if board[0][2] == board[1][1] == board[2][0] != '':
        return board[0][2]
    if all(all(cell != '' for cell in row) for row in board):
        return 'Tie'
    return None

# Main game loop
while not game_over:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()
        elif event.type == pygame.MOUSEBUTTONDOWN and winner is None:
            x, y = event.pos
            col = x // GRID_SIZE
            row = y // GRID_SIZE
            if board[row][col] == '':
                board[row][col] = current_player
                current_player = 'O' if current_player == 'X' else 'X'
                winner = check_win()

    draw_grid()  
    draw_symbols()

    if winner:
        if winner == 'Tie':
            result_text = GAME_FONT.render("Egalité", True, (0, 0, 0))
        else:
            result_text = GAME_FONT.render(f"{winner} EST LE GAGNANT!", True, (0, 0, 0))
        screen.blit(result_text, (SCREEN_WIDTH // 2 - result_text.get_width() // 2, SCREEN_HEIGHT // 2 - result_text.get_height() // 2))
        pygame.display.flip()
        pygame.time.delay(2000)  
        pygame.quit()
        sys.exit()
    
    pygame.display.flip()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\raara\Documents\DigitalLab\Algo\Algo\Runtrack-Python\day05\Job OXO.ipynb Cell 1 line 9
#      <a href='vscode-notebook-cell:/c%3A/Users/raara/Documents/DigitalLab/Algo/Algo/Runtrack-Python/day05/Job%20OXO.ipynb#W0sZmlsZQ%3D%3D?line=94'>95</a>     pygame.time.delay(2000)  # Pause for 2 seconds
#      <a href='vscode-notebook-cell:/c%3A/Users/raara/Documents/DigitalLab/Algo/Algo/Runtrack-Python/day05/Job%20OXO.ipynb#W0sZmlsZQ%3D%3D?line=95'>96</a>     pygame.quit()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/raara/Documents/DigitalLab/Algo/Algo/Runtrack-Python/day05/Job%20OXO.ipynb#W0sZmlsZQ%3D%3D?line=96'>97</a>     sys.exit()
#      <a href='vscode-notebook-cell:/c%3A/Users/raara/Documents/DigitalLab/Algo/Algo/Runtrack-Python/day05/Job%20OXO.ipynb#W0sZmlsZQ%3D%3D?line=98'>99</a> pygame.display.flip()
#
# NameError: name 'sys' is not defined
